# %%
import joblib
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
model=joblib.load('C:/Users/natha/OneDrive/Documents/GitHub/March Madness Linear Regression/Joblib/march_madness.joblib')
# Out:
# c:\Users\natha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator BayesianRidge from version 1.5.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# c:\Users\natha\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:380: InconsistentVersionWarning: Trying to unpickle estimator SelectKBest from version 1.5.1 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
raw_data=pd.read_csv('C:/Users/natha/OneDrive/Documents/GitHub/March Madness Linear Regression/csvs/stats_2025.csv')
teams=pd.read_csv('C:/Users/natha/OneDrive/Documents/GitHub/March Madness Linear Regression/csvs/2025_teams.csv')

# %%
drops= [33, 32, 31, 29, 28, 27, 15 ]
cleand=raw_data.drop(raw_data.columns[drops], axis=1)

# %%
cleand
# Out:
#                        rank  team  conf      record  adjoe     oe Rank  adjde  \
# 1                   Houston   B12  30-4  124.776270      9   88.104534      1
# 2                      Duke   ACC  31-3  128.560273      2   91.270011      4
# 3                    Auburn   SEC  28-5  129.177131      1   93.747192     12
# 4                   Florida   SEC  30-4  127.815939      3   94.087498     13
# 5                   Alabama   SEC  25-8  127.731396      4   96.423551     28
# ..                      ...   ...   ...         ...    ...         ...    ...
# 360             The Citadel    SC  5-25   93.816607    356  117.481548    352
# 361             Chicago St.   NEC  4-28   92.578332    361  116.200259    343
# 362              Coppin St.  MEAC  6-24   87.932272    363  112.519329    300
# 363     Arkansas Pine Bluff  SWAC  6-25   95.096632    347  121.802633    361
# 364  Mississippi Valley St.  SWAC  3-28   82.920628    364  125.302822    364
#
# ...

# %%
merged_table=pd.merge(cleand, teams, left_on='rank', right_on='team', how='inner')

# %%
merged_table.columns
# Out:
# Index(['rank', 'team_x', 'conf', 'record', 'adjoe', 'oe Rank', 'adjde',
#        'de Rank', 'barthag', 'rank.1', 'proj. W', 'Proj. L', 'Pro Con W',
#        'Pro Con L', 'Con Rec.', 'ncsos', 'consos', 'Proj. SOS',
#        'Proj. Noncon SOS', 'Proj. Con SOS', 'elite SOS', 'elite noncon SOS',
#        'Opp OE', 'Opp DE', 'Opp Proj. OE', 'Opp Proj DE', 'Qual D', 'ConPF',
#        'ConPA', 'ConPoss', 'ConOE', 'ConDE', 'ConSOSRemain', 'Conf Win%',
#        'WAB', 'WAB Rk', 'Fun Rk, adjt', 'team_y', 'Seed'],
#       dtype='object')

# %%
merged_table.sort_values(by=['Seed'])
# Out:
#                 rank team_x   conf      record  adjoe     oe Rank  adjde  \
# 0            Houston    B12   30-4  124.776270      9   88.104534      1
# 1               Duke    ACC   31-3  128.560273      2   91.270011      4
# 2             Auburn    SEC   28-5  129.177131      1   93.747192     12
# 3            Florida    SEC   30-4  127.815939      3   94.087498     13
# 4            Alabama    SEC   25-8  127.731396      4   96.423551     28
# 5          Tennessee    SEC   27-7  119.422783     20   91.208312      3
# 12      Michigan St.    B10   27-6  116.922525     35   91.950012      5
# 14        St. John's     BE   30-4  112.659287     72   89.277858      2
# 7           Iowa St.    B12   24-9  118.966396     21   92.487800      8
# 6         Texas Tech    B12   25-8  126.044938      6   96.856373     32
# 11         Wisconsin    B10   26-9  122.471961     13   96.256880     27
# 16          Kentucky    SEC  22-11  123.907683     11   98.756460     48
# ...
